# %% [markdown]
# <a href="https://colab.research.google.com/github/AryWirakusuma/tugaspokemon/blob/main/projekkelompokpokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

sns.set(context='talk', palette='hls')

# %%
data = pd.read_csv('pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# **MEMVISUALISASIKAN DATA**

# %%
df = pd.read_csv('pokemon.csv')
x = [df['Type 1'].value_counts()['Grass'], 
     df['Type 1'].value_counts()['Steel'], 
     df['Type 1'].value_counts()['Dark'], 
     df['Type 1'].value_counts()['Dragon'],
     df['Type 1'].value_counts()['Ghost'],
     df['Type 1'].value_counts()['Rock'],
     df['Type 1'].value_counts()['Psychic'],
     df['Type 1'].value_counts()['Fighting'],
     df['Type 1'].value_counts()['Fairy'],
     df['Type 1'].value_counts()['Ground'], 
     df['Type 1'].value_counts()['Electric'],
     df['Type 1'].value_counts()['Poison'],  
     df['Type 1'].value_counts()['Normal'],
     df['Type 1'].value_counts()['Bug'],
     df['Type 1'].value_counts()['Water'],  
     df['Type 1'].value_counts()['Fire'],       
     df['Type 1'].value_counts()['Flying'],
     800-776]
z = np.sum(x)
print(x)
print(z)



y = ["grass", "Steel", "Dark", 
     "Dragon", "Ghost", "Rock", 
     "Psychic", "Fighting", "Fairy", 
     "Ground", "Electric", "Poison", 
     "Normal", "Bug", "Water", 
     "Fire", "flying", "NULL"] # UDah lengkap semua
plt.bar(y, x)
  
# Adding Title to the Plot
plt.title("Bar Plot")
  
# Setting the X and Y labels
plt.xlabel('Type 1')
plt.ylabel('Num')
  
plt.show()
# Out:
# [70, 27, 31, 32, 32, 44, 57, 27, 17, 32, 44, 28, 98, 69, 112, 52, 4, 24]
# 800

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
#df1 = df.dropna(thresh = 1)
plt.scatter(df['Attack'], df['Type 1'])
  
# Adding Title to the Plot
plt.title("Bar Plot")
  
# Setting the X and Y labels
plt.xlabel('Attack Power')
plt.ylabel('Type 1')
  
plt.show()

# %%
df = pd.read_csv('pokemon.csv')
df['Count'] = 1
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary  Count
# 0     45           1      False      1
# 1     60           1      False      1
# 2     80           1      False      1
# 3     80           1      False      1
# 4     65           1      False      1

# %%
data = df.groupby(['Type 1']).count().reset_index()
data.sort_values('Count', ascending=True, inplace=True)
data.head()
# Out:
#       Type 1   #  Name  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 7     Flying   4     4       2   4       4        4        4        4      4
# 4      Fairy  17    17       2  17      17       17       17       17     17
# 11       Ice  24    24      11  24      24       24       24       24     24
# 5   Fighting  27    26       7  27      27       27       27       27     27
# 16     Steel  27    27      22  27      27       27       27       27     27
#
#     Generation  Legendary  Count
# 7            4          4      4
# 4           17         17     17
# 11          24         24     24
# 5           27         27     27
# 16          27         27     27

# %%
fig = plt.figure(figsize=(6,4))
ax = plt.axes()
ax.bar(data['Type 1'],data['Count'])
plt.xticks(rotation=90)
plt.show()

# %%
data = df.groupby(['Type 1', 'Legendary']).count()[['Count']].reset_index()
data = data.set_index(['Type 1', 'Legendary']).Count
data.head()
# Out:
# Type 1  Legendary
# Bug     False        69
# Dark    False        29
#         True          2
# Dragon  False        20
#         True         12
# Name: Count, dtype: int64

# %%
data.unstack().plot(kind = 'bar', stacked = True)

# %%
data = pd.read_csv('pokemon.csv')

# %%
data.boxplot(column='Attack',by = 'Legendary')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country, population]
zipped = list(zip(list_label, list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
data1 = data.loc[:, ["Attack", "Defense", "Speed"]]
data1.plot()

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind="scatter", x="Attack", y="Defense")
plt.show()

# %%
numeric_columns = data.drop('Type 1', axis=1).columns

# %%
correlation_matrix = data[numeric_columns].corr()

plt.figure(figsize=(18, 15))
sns.heatmap(correlation_matrix, annot=True, vmin=-1.0, vmax=1.0)
plt.show()
